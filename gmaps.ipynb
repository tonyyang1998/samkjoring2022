# %%
with open('gmapsAPIkey.txt') as f:
    api_key = f.readline()
    f.close

import gmaps
import googlemaps
from xlwt import Workbook
import TestExcel as te
from datetime import datetime
import pandas as pd
import math

gmaps.configure(api_key='AIzaSyCf7qO0Nt4SRxGpx6BLxJh9ZF8sLsrLFBI')
now=datetime.now()
wb = Workbook()


#filename = "All_Origins_and_destinations.xlsx"
#file_to_save = 'Distance matrix/distance matrix result.xls'

df = pd.read_excel("All_Origins_and_destinations.xlsx")
rows = df.shape[0]

# Create an empty dictionary to store the locations and their X and Y coordinates
all_origins = {}
all_destinations = {}

def read_from_file():

    # Start iterating from the first row
    for i in range(rows):
        # Get the current row
        row = df.iloc[i]
        
        # Get the location name
        origin = row["Origins"]
        
        # Get the X and Y coordinates
        x = row["Origin X"]
        y = row["Origin Y"]
        
        # Add the location and its X and Y coordinates to the dictionary
        all_origins[origin] = (x, y)
        
        destination = row["Destination"]
        xx = row["Destination X"]
        yy = row["Destination Y"]

        all_destinations[destination] = (xx, yy)

    all_destinations.popitem()

read_from_file()

def compare_locations(locations1, locations2):
    results = {}
    for location1, (x1, y1) in locations1.items():
        for location3, (x3, y3) in locations1.items():
            if location1 != location3:
                results[(location1, location3)] = ((x1, y1), (x3, y3))
        for location2, (x2, y2) in locations2.items():
            results[(location1, location2)] = ((x1, y1), (x2, y2))
        
    for location4, (x4, y4) in locations2.items():
        for location5, (x5, y5) in locations2.items():
            if location4 != location5:
                results[(location4, location5)] = ((x4, y4), (x5, y5))
    return results

location_pair = compare_locations(all_origins, all_destinations)

# Print the locations and their X and Y coordinates
gmaps = googlemaps.Client(key = 'AIzaSyCf7qO0Nt4SRxGpx6BLxJh9ZF8sLsrLFBI')

def get_distances():
    distance_matrix = {}
    for loc_pair in location_pair:
        loc1 = (location_pair[loc_pair][0][1], location_pair[loc_pair][0][0])
        loc2 = (location_pair[loc_pair][1][1], location_pair[loc_pair][1][0])

        directions = gmaps.directions(loc1, loc2, mode="driving", avoid = "ferries", departure_time=now)
        duration = directions[0]['legs'][0]['duration']['text']
        distance_matrix[loc_pair] = duration
    return distance_matrix


#print(get_distances())

import requests

locations = {('Knappskog', 'Kolltveit'): '7 mins', ('Knappskog', 'Kårtveit'): '8 mins', ('Knappskog', 'Telavåg'): '29 mins', ('Knappskog', 'Straume'): '11 mins', ('Knappskog', 'Knarrevik'): '12 mins', ('Knappskog', 'Bildøyna'): '8 mins', ('Knappskog', 'Spjeld'): '2 mins', ('Knappskog', 'Foldnes'): '14 mins', ('Knappskog', 'Brattholmen'): '15 mins', ('Knappskog', 'Blomøy'): '22 mins', ('Knappskog', 'Hellesøy'): '41 mins', ('Knappskog', 'Straume'): '15 mins', ('Knappskog', 'Arefjord'): '13 mins', ('Knappskog', 'Ebbesvik'): '17 mins', ('Knappskog', 'Landro'): '10 mins', ('Knappskog', 'Hjelteryggen'): '13 mins', ('Knappskog', 'Skogsvåg'): '20 mins', ('Knappskog', 'Kleppestø'): '32 mins', ('Knappskog', 'Solsvik'):
locs = list(locations.keys())


def create_distance_matrix(api_key, origins, destinations):
    # Construct the API URL
    url = "https://maps.googleapis.com/maps/api/distancematrix/json?"
    url += "origins=" + "|".join(origins)
    url += "&destinations=" + "|".join(destinations)
    url += "&key=" + api_key
    
    # Send a request to the API
    response = requests.get(url)
    
    # Extract the distance matrix from the response
    distances = response.json()["rows"]
    
    return distances

def return_distance_matrix():
    result_dict = {}
    for pair in locs:
        result = create_distance_matrix("AIzaSyCf7qO0Nt4SRxGpx6BLxJh9ZF8sLsrLFBI", [pair[0] + ", Norway"], [pair[1] + ", Norway"])
        result_dict[pair] = math.ceil(int(result[0]['elements'][0]['duration']['value'])/60)
    return result_dict


print(return_distance_matrix())


kolltveit = (60.352223,5.087813)
bergenhus = (60.395409,5.326163)
#Create the map
#fig = gmaps.figure()
#layer = gmaps.directions_layer(kolltveit, bergenhus, travel_mode='DRIVING')
#fig.add_layer(layer)

#calculate
gmaps = googlemaps.Client(key = 'AIzaSyCf7qO0Nt4SRxGpx6BLxJh9ZF8sLsrLFBI')
directions = gmaps.directions(kolltveit, bergenhus, mode="driving", avoid = "ferries", departure_time=now)
print("kolltveit til bergenhus distanse:", directions[0]['legs'][0]['distance']['text'])
print("kolltveit til bergenhus tid:", directions[0]['legs'][0]['duration']['text'])
#fig
# Out:
# {('Knappskog', 'Kolltveit'): 6, ('Knappskog', 'Kårtveit'): 8, ('Knappskog', 'Telavåg'): 28, ('Knappskog', 'Straume'): 9, ('Knappskog', 'Knarrevik'): 10, ('Knappskog', 'Bildøyna'): 7, ('Knappskog', 'Spjeld'): 2, ('Knappskog', 'Foldnes'): 13, ('Knappskog', 'Brattholmen'): 12, ('Knappskog', 'Blomøy'): 22, ('Knappskog', 'Hellesøy'): 41, ('Knappskog', 'Arefjord'): 12, ('Knappskog', 'Ebbesvik'): 15, ('Knappskog', 'Landro'): 10, ('Knappskog', 'Hjelteryggen'): 13, ('Knappskog', 'Skogsvåg'): 20, ('Knappskog', 'Kleppestø'): 21, ('Knappskog', 'Solsvik'): 12, ('Knappskog', 'Rongøy'): 17, ('Knappskog', 'Hammarsland'): 19, ('Knappskog', 'Træsneset'): 23, ('Knappskog', 'Tofterøy'): 31, ('Knappskog', 'Bergenhus'): 27, ('Knappskog', 'Laksevåg'): 20, ('Knappskog', 'Ytrebygda'): 25, ('Knappskog', 'Årstad'): 27, ('Kolltveit', 'Knappskog'): 6, ('Kolltveit', 'Kårtveit'): 13, ('Kolltveit', 'Telavåg'): 26, ('Kolltveit', 'Straume'): 7, ('Kolltveit', 'Knarrevik'): 7, ('Kolltveit', 'Bildøyna'): 5, ('Kolltveit'
# ...
