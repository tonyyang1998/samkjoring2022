# %%
with open('gmapsAPIkey.txt') as f:
    api_key = f.readline()
    f.close

import gmaps
import googlemaps
from xlwt import Workbook
import TestExcel as te
from datetime import datetime
import pandas as pd

gmaps.configure(api_key='AIzaSyCf7qO0Nt4SRxGpx6BLxJh9ZF8sLsrLFBI')
now=datetime.now()
wb = Workbook()


#filename = "All_Origins_and_destinations.xlsx"
#file_to_save = 'Distance matrix/distance matrix result.xls'



df = pd.read_excel("All_Origins_and_destinations.xlsx")
rows = df.shape[0]

# Create an empty dictionary to store the locations and their X and Y coordinates
all_origins = {}
all_destinations = {}

def read_from_file():

    # Start iterating from the first row
    for i in range(rows):
        # Get the current row
        row = df.iloc[i]
        
        # Get the location name
        origin = row["Origins"]
        
        # Get the X and Y coordinates
        x = row["Origin X"]
        y = row["Origin Y"]
        
        # Add the location and its X and Y coordinates to the dictionary
        all_origins[origin] = (x, y)
        
        destination = row["Destination"]
        xx = row["Destination X"]
        yy = row["Destination Y"]

        all_destinations[destination] = (xx, yy)

    all_destinations.popitem()

read_from_file()

def compare_locations(all_origins, all_destinations):
    results = {}
    for location1, (x1, y1) in all_origins.items():
        for location2, (x2, y2) in all_destinations.items():
            if location1 != location2:
                results[(location1, location2)] = ((x1, y1), (x2, y2))
    return results

print(compare_locations(all_origins, all_destinations))



# Print the locations and their X and Y coordinates
for location, (x, y) in all_origins.items():
    print(f"{location}: ({x}, {y})")

for location, (x, y) in all_destinations.items():
    print(f"{location}: ({x}, {y})")

print(all_destinations)




kolltveit = (60.352223,5.087813)
bergenhus = (60.395409,5.326163)
#Create the map
fig = gmaps.figure()
layer = gmaps.directions_layer(kolltveit, bergenhus, travel_mode='DRIVING')
fig.add_layer(layer)

#calculate
gmaps = googlemaps.Client(key = 'AIzaSyCf7qO0Nt4SRxGpx6BLxJh9ZF8sLsrLFBI')
directions = gmaps.directions(kolltveit, bergenhus, mode="driving", avoid = "ferries", departure_time=now)
print("kolltveit til bergenhus distanse:", directions[0]['legs'][0]['distance']['text'])
print("kolltveit til bergenhus tid:", directions[0]['legs'][0]['duration']['text'])
#fig
# Out:
# {('Knappskog', 'Bergenhus'): ((5.055929, 60.382878), (5.326163, 60.395409)), ('Knappskog', 'Laksevåg'): ((5.055929, 60.382878), (5.264793, 60.379099)), ('Knappskog', 'Ytrebygda'): ((5.055929, 60.382878), (5.258676, 60.290962)), ('Knappskog', 'Årstad'): ((5.055929, 60.382878), (5.352355, 60.363501)), ('Kolltveit', 'Bergenhus'): ((5.087813, 60.352223), (5.326163, 60.395409)), ('Kolltveit', 'Laksevåg'): ((5.087813, 60.352223), (5.264793, 60.379099)), ('Kolltveit', 'Ytrebygda'): ((5.087813, 60.352223), (5.258676, 60.290962)), ('Kolltveit', 'Årstad'): ((5.087813, 60.352223), (5.352355, 60.363501)), ('Kårtveit', 'Bergenhus'): ((4.993453, 60.388651), (5.326163, 60.395409)), ('Kårtveit', 'Laksevåg'): ((4.993453, 60.388651), (5.264793, 60.379099)), ('Kårtveit', 'Ytrebygda'): ((4.993453, 60.388651), (5.258676, 60.290962)), ('Kårtveit', 'Årstad'): ((4.993453, 60.388651), (5.352355, 60.363501)), ('Telavåg', 'Bergenhus'): ((4.982022, 60.261564), (5.326163, 60.395409)), ('Telavåg', 'Laksevåg'): ((4.982022, 60.261564), (5.264793, 60.379099)), ('Telavåg', 'Ytrebygda'): ((4.982022, 60.261564), (5.258676, 60.290962)), ('Telavåg', 'Årstad'): ((4.982022, 60.261564), (5.352355, 60.363501)), ('Straume', 'Bergenhus'): ((5.121333, 60.356561), (5.326163, 60.395409)), ('Straume', 'Laksevåg'): ((5.121333, 60.356561), (5.264793, 60.379099)), ('Straume', 'Ytrebygda'): ((5.121333, 60.356561), (5.258676, 60.290962)), ('Straume', 'Årstad'): ((5.121333, 60.356561), (5.352355, 60.363501)), ('Knarrevik', 'Bergenhus'): ((5.153025, 60.368083), (5.326163, 60.395409)), ('Knarrevik', 'Laksevåg'): ((5.153025, 60.368083), (5.264793, 60.379099)), ('Knarrevik', 'Ytrebygda'): ((5.153025, 60.368083), (5.258676, 60.290962)), ('Knarrevik', 'Årstad'): ((5.153025, 60.368083), (5.352355, 60.363501)), ('Bildøyna', 'Bergenhus'): ((5.106085, 60.354085), (5.326163, 60.395409)), ('Bildøyna', 'Laksevåg'): ((5.106085, 60.354085), (5.264793, 60.379099)), ('Bildøyna', 'Ytrebygda'): ((5.106085, 60.354085), (5.258676, 60.290962)), ('Bildøyna', 'Årstad'): ((5.106085, 60.354085), (5.352355, 60.363501)), ('Spjeld', 'Bergenhus'): ((5.039608, 60.390343), (5.326163, 60.395409)), ('Spjeld', 'Laksevåg'): ((5.039608, 60.390343), (5.264793, 60.379099)), ('Spjeld', 'Ytrebygda'): ((5.039608, 60.390343), (5.258676, 60.290962)), ('Spjeld', 'Årstad'): ((5.039608, 60.390343), (5.352355, 60.363501)), ('Foldnes', 'Bergenhus'): ((5.106568, 60.375988), (5.326163, 60.395409)), ('Foldnes', 'Laksevåg'): ((5.106568, 60.375988), (5.264793, 60.379099)), ('Foldnes', 'Ytrebygda'): ((5.106568, 60.375988), (5.258676, 60.290962)), ('Foldnes', 'Årstad'): ((5.106568, 60.375988), (5.352355, 60.363501)), ('Brattholmen', 'Bergenhus'): ((5.152274, 60.354616), (5.326163, 60.395409)), ('Brattholmen', 'Laksevåg'): ((5.152274, 60.354616), (5.264793, 60.379099)), ('Brattholmen', 'Ytrebygda'): ((5.152274, 60.354616), (5.258676, 60.290962)), ('Brattholmen', 'Årstad'): ((5.152274, 60.354616), (5.352355, 60.363501)), ('Blomøy', 'Bergenhus'): ((4.892748, 60.538108), (5.326163, 60.395409)), ('Blomøy', 'Laksevåg'): ((4.892748, 60.538108), (5.264793, 60.379099)), ('Blomøy', 'Ytrebygda'): ((4.892748, 60.538108), (5.258676, 60.290962)), ('Blomøy', 'Årstad'): ((4.892748, 60.538108), (5.352355, 60.363501)), ('Hellesøy', 'Bergenhus'): ((4.790867, 60.661021), (5.326163, 60.395409)), ('Hellesøy', 'Laksevåg'): ((4.790867, 60.661021), (5.264793, 60.379099)), ('Hellesøy', 'Ytrebygda'): ((4.790867, 60.661021), (5.258676, 60.290962)), ('Hellesøy', 'Årstad'): ((4.790867, 60.661021), (5.352355, 60.363501)), ('Vågo', 'Bergenhus'): ((5.124566, 60.388821), (5.326163, 60.395409)), ('Vågo', 'Laksevåg'): ((5.124566, 60.388821), (5.264793, 60.379099)), ('Vågo', 'Ytrebygda'): ((5.124566, 60.388821), (5.258676, 60.290962)), ('Vågo', 'Årstad'): ((5.124566, 60.388821), (5.352355, 60.363501)), ('Arefjord', 'Bergenhus'): ((5.142463, 60.358855), (5.326163, 60.395409)), ('Arefjord', 'Laksevåg'): ((5.142463, 60.358855), (5.264793, 60.379099)), ('Arefjord', 'Ytrebygd ...
# Knappskog: (5.055929, 60.382878)
# Kolltveit: (5.087813, 60.352223)
# Kårtveit: (4.993453, 60.388651)
# Telavåg: (4.982022, 60.261564)
# Straume: (5.121333, 60.356561)
# Knarrevik: (5.153025, 60.368083)
# Bildøyna: (5.106085, 60.354085)
# Spjeld: (5.039608, 60.390343)
# Foldnes: (5.106568, 60.375988)
# Brattholmen: (5.152274, 60.354616)
# Blomøy: (4.892748, 60.538108)
# Hellesøy: (4.790867, 60.661021)
# Vågo: (5.124566, 60.388821)
# Arefjord: (5.142463, 60.358855)
# Ebbesvika: (5.140128, 60.336068)
# Landro: (4.967209, 60.423365)
# Hjelteryggen: (5.154482, 60.381361)
# Skogsvåg: (5.097186, 60.25994)
# Kleppe: (5.135965, 60.18781)
# Solsvik: (4.966409, 60.431002)
# Rongøy: (4.915516, 60.507616)
# Hammersland: (5.068799, 60.25957)
# Vorland: (5.067745, 60.227445)
# Tofterøy: (5.05251, 60.18589)
# Bergenhus: (5.326163, 60.395409)
# Laksevåg: (5.264793, 60.379099)
# Ytrebygda: (5.258676, 60.290962)
# Årstad: (5.352355, 60.363501)
# {'Bergenhus': (5.326163, 60.395409), 'Laksevåg': (5.264793, 60.379099), 'Ytrebygda': (5.258676, 60.290962), 'Årstad': (5.352355, 60.363501)}
# kolltveit til bergenhus distanse: 19.7 km
# kolltveit til bergenhus tid: 25 mins
